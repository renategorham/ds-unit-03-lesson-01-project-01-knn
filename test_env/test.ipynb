# %%
import lib.create_test_data as mk_data
import lib.t_normalize as t_norm
import lib.t_train_test as t_tt
import lib.t_my_knn as t_knn
import lib.t_confusion_average as t_cm
import lib.t_confusion_count as t_cc

# %%
data = mk_data.new_data()

# %%
a, b = t_tt.train_test(data,'class')

# %%
c, d, e = t_norm.normalize(a, b, 'class', 'aspect_1', 
                                         'aspect_2')

# %%
df = t_knn.knn(d, e, 'class', 'aspect_1', 'aspect_2', 'A', 'B')

# %%
by_mean = t_cm.confusion_matrix('./data/analyzed.csv', 'test_class', 
                                'result_by_mag', 'A', 'B')

# %%
by_count = t_cc. confusion_matrix('./data/analyzed.csv', 'test_class', 
                                  'A', 'B')
by_count
# Out:
#     true_pos  true_neg  false_pos  false_neg  ties  tp_rate  fp_rate
# k
# 1         30        50          0          0     0      1.0      0.0
# 2         30        50          0          0     0      1.0      0.0
# 3         30        50          0          0     0      1.0      0.0
# 4         30        50          0          0     0      1.0      0.0
# 5         30        50          0          0     0      1.0      0.0
# 6         30        50          0          0     0      1.0      0.0
# 7         30        50          0          0     0      1.0      0.0
# 8         30        50          0          0     0      1.0      0.0
# 9         30        50          0          0     0      1.0      0.0
# 10        30        50          0          0     0      1.0      0.0
# 11        30        50          0          0     0      1.0      0.0
# 12        30        50          0          0     0      1.0      0.0
# 13        30        50          0          0     0      1.0      0.0
# 14        30        50          0          0     0      1.0      0.0
# 15        30        50          0          0     0      1.0      0.0
# 16        30        50          0          0     0      1.0      0.0
# 17        30        50          0          0     0      1.0      0.0
# 18        30        50          0          0     0      1.0      0.0
# 19        30        50          0          0     0      1.0      0.0
# 20        30        50          0          0     0      1.0      0.0
